# %% [markdown]
# In the same directory, make sure the following files exist:
# 1. $\texttt{questions-words.txt}$, which can be downloaded from https://github.com/nicholas-leonard/word2vec/blob/master/questions-words.txt

# %%
# !pip install transformers
# !pip install gensim
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/kwib/.local/lib/python3.9/site-packages (4.26.1)
# Requirement already satisfied: numpy>=1.17 in /home/kwib/.local/lib/python3.9/site-packages (from transformers) (1.24.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /home/kwib/.local/lib/python3.9/site-packages (from transformers) (0.12.0)
# Requirement already satisfied: tqdm>=4.27 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (4.62.3)
# Requirement already satisfied: filelock in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (3.3.1)
# Requirement already satisfied: regex!=2019.12.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (2021.8.3)
# Requirement already satisfied: requests in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (2.26.0)
# Requirement already satisfied: pyyaml>=5.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (6.0)
# Requirement already satisfied: packaging>=20.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from transformers) (21.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/kwib/.local/lib/python3.9/site-packages (from transformers) (0.13.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/kwib/.local/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from packaging>=20.0->transformers) (3.0.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->transformers) (1.26.7)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in /home/kwib/.local/lib/python3.9/site-packages (4.3.0)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /home/kwib/.local/lib/python3.9/site-packages (from gensim) (2.0.5)
# Requirement already satisfied: smart-open>=1.8.1 in /home/kwib/.local/lib/python3.9/site-packages (from gensim) (6.3.0)
# Requirement already satisfied: numpy>=1.18.5 in /home/kwib/.local/lib/python3.9/site-packages (from gensim) (1.24.2)
# Requirement already satisfied: scipy>=1.7.0 in /home/kwib/.local/lib/python3.9/site-packages (from gensim) (1.10.1)
# Requirement already satisfied: pyfume in /home/kwib/.local/lib/python3.9/site-packages (from FuzzyTM>=0.4.0->gensim) (0.2.25)
# Requirement already satisfied: pandas in /home/kwib/.local/lib/python3.9/site-packages (from FuzzyTM>=0.4.0->gensim) (2.0.0)
# Requirement already satisfied: pytz>=2020.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2021.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/kwib/.local/lib/python3.9/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: six>=1.5 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Requirement already satisfied: simpful in /home/kwib/.local/lib/python3.9/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.9.0)
# Requirement already satisfied: fst-pso in /home/kwib/.local/lib/python3.9/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Requirement already satisfied: miniful in /home/kwib/.local/lib/python3.9/site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: requests in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.26.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /sw/pkgs/arc/python3.9-anaconda/2021.11/lib/python3.9/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim) (3.2)

# %%
### Standard libraries
import operator
from tqdm import tqdm
import numpy as np
import pandas as pd


### For BART
from transformers import BartModel, BartTokenizer
# Out:
# 2023-05-23 21:14:49.239318: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-23 21:14:49.382417: W tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/slurm/lib64:
# 2023-05-23 21:14:49.382459: I tensorflow/tsl/cuda/cudart_stub.cc:28] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-05-23 21:14:49.426012: E tensorflow/tsl/lib/monitoring/collection_registry.cc:81] Cannot register 2 metrics with the same name: /tensorflow/core/bfc_allocator_delay
# 2023-05-23 21:14:50.787744: W tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libnvinfer.so.8'; dlerror: libnvinfer.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/slurm/lib64:
# 2023-05-23 21:14:50.787848: W tensorflow/tsl/platform/default/dso_loader.cc:66] Could not load dynamic library 'libnvinfer_plugin.so.8'; dlerror: libnvinfer_plugin.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /opt/slurm/lib64:
# 2023-05-23 21:14:50.787855: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
model = BartModel.from_pretrained("facebook/bart-base")
embedding_matrix = model.encoder.embed_tokens.weight
tokenizer = BartTokenizer.from_pretrained('facebook/bart-base')

token_list = []

for token in tokenizer.get_vocab().keys():
    token_list.append(token)
    
token_list = np.array(token_list)

def convert_word(x):
    if x[0] == 'Ġ':
        return x[1:].lower()
    else:
        return x.lower()
    
lower_case_token = []
lower_case_token_idx = []

for i in range(len(token_list)):
    converted = convert_word(token_list[i])
    if converted not in lower_case_token:
        lower_case_token.append(converted)
        lower_case_token_idx.append(i)
        
lower_case_token = np.array(lower_case_token)

embedding_matrix = embedding_matrix.detach().numpy()[lower_case_token_idx,:]
emb_mat_npy = embedding_matrix.T

get_embedding_dict = {lower_case_token[i]: embedding_matrix[i] for i in range(len(lower_case_token))}
token_list_set = set(get_embedding_dict.keys())

def get_most_similar_words(emb, sim_metric):
    sim_list = []
    dotprod = np.dot(emb, emb_mat_npy)
    den1 = np.sqrt(np.sum(emb**2))
    den2 = np.sqrt(np.sum(((emb_mat_npy)**2),axis=0))
    if sim_metric == 'dot':
        sim_list = dotprod
    elif sim_metric == 'cosine':
        sim_list = (dotprod/(den1 * den2))
    temp = [(lower_case_token[i], sim_list[i]) for i in range(len(lower_case_token))]
    return sorted(temp,key=operator.itemgetter(1),reverse=True)

def analogy(a, b, c, d):
    if a in token_list_set and b in token_list_set and c in token_list_set and d in token_list_set:
        a_emb, b_emb = get_embedding_dict[a], get_embedding_dict[b]
        c_emb, d_emb = get_embedding_dict[c], get_embedding_dict[d]
        f_emb = c_emb - a_emb + b_emb
        
        ## Cosine similarity of d and f
        cos_sim = np.sum(d_emb * f_emb)/np.sqrt(np.sum(d_emb**2) * np.sum(f_emb**2))
        
        ## Most similar
        most_sim = get_most_similar_words(f_emb, 'cosine')
        most_sim = [x for x in most_sim if x[0] not in {a,b,c}]
        rank_of_d = np.where(np.array([x[0] for x in most_sim]) == d)[0][0] + 1
        top_10 = most_sim[:10] 
        
        return (cos_sim, rank_of_d, top_10)
        
    else:
        return 'At least one word is not in the vocabulary list'

# %%
all_in_vocab = []
result = []
categories = []

category = 'none'

with open('questions-words.txt') as file:
    for line in tqdm(file):
        if line[0] == ':':
            category = line[2:].strip('\n')
        if line[0] != ':':
            a, b, c, d = [x.lower() for x in line.strip('\n').split(' ')]
            temp = analogy(a, b, c, d)
            if temp != 'At least one word is not in the vocabulary list':
                all_in_vocab.append((a, b, c, d))
                result.append(temp)
                categories.append(category)
                
bart_res = pd.DataFrame()
bart_res['task'] = all_in_vocab
bart_res['cosine'] = [x[0] for x in result]
bart_res['rank'] = [x[1] for x in result]
bart_res['top_10'] = [x[2] for x in result]
bart_res['category'] = categories
# Out:
# 19558it [34:51,  9.35it/s]

# %%
bart_res
# Out:
#                                       task    cosine  rank
# 0          (athens, greece, baghdad, iraq)  0.642231     1  \
# 1      (athens, greece, bangkok, thailand)  0.695670     1
# 2         (athens, greece, beijing, china)  0.661186     1
# 3        (athens, greece, berlin, germany)  0.601279     1
# 4      (athens, greece, bern, switzerland)  0.364594     1
# ...                                    ...       ...   ...
# 10996       (write, writes, speak, speaks)  0.772114     1
# 10997         (write, writes, talk, talks)  0.572955     2
# 10998       (write, writes, think, thinks)  0.704055     1
# 10999         (write, writes, walk, walks)  0.704394     1
# 11000         (write, writes, work, works)  0.580971     1
#
#                                                   top_10
# 0      [(iraq, 0.64223135), (iraqi, 0.55553335), (syr...  \
# 1      [(thailand, 0.69567), (cambodia, 0.4977392), (...
# 2      [(china, 0.661186), (chinese, 0.47734934), (ja...
# 3      [(germany, 0.6012795), (france, 0.4640275), (d...
# 4      [(switzerland, 0.3645942), (spain, 0.3280067),...
# ...                                                  ...
# 10996  [(speaks, 0.7721138), (spoke, 0.6394584), (spe...
# 10997  [(talked, 0.57785845), (talks, 0.57295513), (t...
# 10998  [(thinks, 0.70405537), (thought, 0.48446873), ...
# 10999  [(walks, 0.70439386), (walked, 0.6366826), (wa...
# 11000  [(works, 0.580971), (worked, 0.49512526), (wor...
#
#                        category
# 0      capital-common-countries
# 1      capital-common-countries
# 2      capital-common-countries
# 3      capital-common-countries
# 4      capital-common-countries
# ...                         ...
# 10996        gram9-plural-verbs
# 10997        gram9-plural-verbs
# 10998        gram9-plural-verbs
# 10999        gram9-plural-verbs
# 11000        gram9-plural-verbs
#
# [11001 rows x 5 columns]

# %%
bart_res.to_csv("bart_res.csv")
