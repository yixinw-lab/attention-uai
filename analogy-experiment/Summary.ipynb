# %%
### Standard libraries
import operator
from tqdm import tqdm
import numpy as np
import pandas as pd
from ast import literal_eval

# %%
bert_res = pd.read_csv("bert_res.csv").iloc[:,1:]
bart_res = pd.read_csv("bart_res.csv").iloc[:,1:]
w2v_res = pd.read_csv("w2v_res.csv").iloc[:,1:]
glove_res = pd.read_csv("glove_res.csv").iloc[:,1:]

# %%
bert_res['task'] = bert_res['task'].apply(literal_eval)
bert_res['top_10'] = bert_res['top_10'].apply(literal_eval)
glove_res['task'] = glove_res['task'].apply(literal_eval)
glove_res['top_10'] = glove_res['top_10'].apply(literal_eval)
w2v_res['task'] = w2v_res['task'].apply(literal_eval)
w2v_res['top_10'] = w2v_res['top_10'].apply(literal_eval)
bart_res['task'] = bart_res['task'].apply(literal_eval)
bart_res['top_10'] = bart_res['top_10'].apply(literal_eval)

# %%
joined = bert_res \
    .merge(w2v_res, how = 'inner', on = 'task') \
    .merge(glove_res, how = 'inner', on = 'task')

joined.columns = ['task', 'cos_bert', 'rank_bert', 'top10_bert', 'to_del', 
                 'cos_w2v', 'rank_w2v', 'top10_w2v', 'to_del_2',
                 'cos_glove', 'rank_glove', 'top10_glove', 'category']

del joined['to_del']
del joined['to_del_2']

bart_res.columns = ['task', 'cos_bart', 'rank_bart', 'top10_bart', 'category']
joined = joined.merge(bart_res, how = 'inner', on = 'task')

del joined['category_x']
joined['category'] = joined['category_y']
del joined['category_y']

joined = joined.drop_duplicates(['task']).reset_index(drop = True)

joined['rank_w2v'] = joined['rank_w2v'].fillna(200000)
joined['type'] = joined['category'].apply(lambda r: 'syn' if r[:4] == 'gram' else 'sem')

# %%
joined.head()
# Out:
#                                   task  cos_bert  rank_bert
# 0      (athens, greece, baghdad, iraq)  0.613978          1  \
# 1  (athens, greece, bangkok, thailand)  0.653616          1
# 2     (athens, greece, beijing, china)  0.527557          4
# 3    (athens, greece, berlin, germany)  0.547957          1
# 4       (athens, greece, cairo, egypt)  0.591381          1
#
#                                           top10_bert   cos_w2v  rank_w2v
# 0  [(iraq, 0.6139779), (mesopotamia, 0.60773236),...  0.459147       9.0  \
# 1  [(thailand, 0.6536159), (cambodia, 0.5840745),...  0.568460       2.0
# 2  [(tianjin, 0.54582757), (nanjing, 0.53440684),...  0.238600   19956.0
# 3  [(germany, 0.5479567), (italy, 0.43626735), (s...  0.548939       2.0
# 4  [(egypt, 0.5913807), (egyptians, 0.53934705), ...  0.574773       1.0
#
#                                            top10_w2v  cos_glove  rank_glove
# 0  [(saddam, 0.48523029685020447), (afghanistan, ...   0.723732         1.0  \
# 1  [(europe, 0.5729362368583679), (thailand, 0.56...   0.770864         1.0
# 2  [(europe, 0.5613299608230591), (poland, 0.5535...   0.775182         1.0
# 3  [(german, 0.5611334443092346), (germany, 0.548...   0.749873         1.0
# 4  [(egypt, 0.5747732520103455), (malta, 0.527613...   0.743846         1.0
#
#                                          top10_glove  cos_bart  rank_bart
# 0  [(iraq, 0.7237322926521301), (iraqi, 0.6456960...  0.642231          1  \
# 1  [(thailand, 0.7708642482757568), (thai, 0.5920...  0.695670          1
# 2  [(china, 0.7751821279525757), (chinese, 0.6065...  0.661186          1
# 3  [(germany, 0.7498731017112732), (german, 0.587...  0.601279          1
# 4  [(egypt, 0.7438464164733887), (egyptian, 0.596...  0.607878          1
#
#                                           top10_bart
# 0  [(iraq, 0.64223135), (iraqi, 0.55553335), (syr...  \
# 1  [(thailand, 0.69567), (cambodia, 0.4977392), (...
# 2  [(china, 0.661186), (chinese, 0.47734934), (ja...
# 3  [(germany, 0.6012795), (france, 0.4640275), (d...
# 4  [(egypt, 0.60787797), (syria, 0.48144093), (mo...
#
#                    category type
# 0  capital-common-countries  sem
# 1  capital-common-countries  sem
# 2  capital-common-countries  sem
# 3  capital-common-countries  sem
# 4  capital-common-countries  sem

# %% [markdown]
# ### Table 1

# %%
joined \
    .groupby('type') \
    .agg({'task': 'count',
          'rank_bert': lambda x: (x == 1).mean(),
          'rank_w2v': lambda x: (x == 1).mean(),
          'rank_glove': lambda x: (x == 1).mean(),
          'rank_bart': lambda x: (x == 1).mean()}) \
    .round(3)
# Out:
#       task  rank_bert  rank_w2v  rank_glove  rank_bart
# type
# sem   2278      0.641     0.234       0.759      0.846
# syn   7244      0.754     0.667       0.692      0.825

# %%
joined \
    .agg({'task': 'count',
            'rank_bert': lambda x: (x == 1).mean(),
            'rank_w2v': lambda x: (x == 1).mean(),
            'rank_glove': lambda x: (x == 1).mean(),
            'rank_bart': lambda x: (x == 1).mean()}) \
    .round(3)
# Out:
# task          9522.000
# rank_bert        0.727
# rank_w2v         0.563
# rank_glove       0.708
# rank_bart        0.830
# dtype: float64

# %% [markdown]
# ### Table 2

# %%
joined \
    .groupby('type') \
    .agg({'task': 'count',
          'cos_bert': 'mean',
          'cos_w2v': 'mean',
          'cos_glove': 'mean',
          'cos_bart': 'mean'}) \
    .round(3)
# Out:
#       task  cos_bert  cos_w2v  cos_glove  cos_bart
# type
# sem   2278      0.50    0.504       0.60     0.525
# syn   7244      0.61    0.582       0.61     0.596

# %%
joined \
    .agg({'task': 'count',
          'cos_bert': 'mean',
          'cos_w2v': 'mean',
          'cos_glove': 'mean',
          'cos_bart': 'mean'}) \
    .round(3)
# Out:
# task         9522.000
# cos_bert        0.584
# cos_w2v         0.564
# cos_glove       0.607
# cos_bart        0.579
# dtype: float64
